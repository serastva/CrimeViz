# %%
import pandas as pd
import os

# %%
crime_df = pd.read_csv("Output/4_crime_data_lat_long_tract.csv")
crime_df
# Out:
#          Incident        Date  Hour NIBRS_Class  \
# 0           79220  2020-01-01     0         120
# 1        59342520  2020-01-01     0         220
# 2       123324720  2020-01-01     0         220
# 3          233120  2020-01-01     0         240
# 4          240920  2020-01-01     0         240
# ...           ...         ...   ...         ...
# 354130  133031021  2021-09-30    23         290
# 354131  133300021  2021-09-30    23         290
# 354132  133300021  2021-09-30    23         23F
# 354133  134942021  2021-09-30    23         290
# 354134  136362221  2021-09-30    23         240
#
#                            Offense_Type   Offense_Grouped  Offense_Count  \
# 0                               Robbery  Burglary/Robbery              1
# 1       Burglary, Breaking and Entering  Burglary/Robbery              1
# 2       Burglary, Breaking and Entering  Burglary/Robbery              1
# 3                   Motor vehicle theft             Theft              1
# ...

# %%
crime_df.dropna(subset = ['Latitude'], inplace = True) 
crime_df
# Out:
#          Incident        Date  Hour NIBRS_Class  \
# 0           79220  2020-01-01     0         120
# 2       123324720  2020-01-01     0         220
# 3          233120  2020-01-01     0         240
# 4          240920  2020-01-01     0         240
# 5          554620  2020-01-01     0         240
# ...           ...         ...   ...         ...
# 354130  133031021  2021-09-30    23         290
# 354131  133300021  2021-09-30    23         290
# 354132  133300021  2021-09-30    23         23F
# 354133  134942021  2021-09-30    23         290
# 354134  136362221  2021-09-30    23         240
#
#                            Offense_Type   Offense_Grouped  Offense_Count  \
# 0                               Robbery  Burglary/Robbery              1
# 2       Burglary, Breaking and Entering  Burglary/Robbery              1
# 3                   Motor vehicle theft             Theft              1
# 4                   Motor vehicle theft             Theft              1
# ...

# %%
crime_df.to_csv('Output/6_Cleaned_lat_long.csv', index=False,)
