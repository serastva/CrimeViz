# %%
import os 
import pandas as pd

# %% [markdown]
# # #Crime_DF  SQL cleanup

# %%
crime_df = pd.read_csv("4_crime_data_lat_long_tract.csv")
crime_df
# Out:
#          Incident        Date  Hour NIBRS_Class  \
# 0           79220  2020-01-01     0         120
# 1        59342520  2020-01-01     0         220
# 2       123324720  2020-01-01     0         220
# 3          233120  2020-01-01     0         240
# 4          240920  2020-01-01     0         240
# ...           ...         ...   ...         ...
# 354130  133031021  2021-09-30    23         290
# 354131  133300021  2021-09-30    23         290
# 354132  133300021  2021-09-30    23         23F
# 354133  134942021  2021-09-30    23         290
# 354134  136362221  2021-09-30    23         240
#
#                            Offense_Type   Offense_Grouped  Offense_Count  \
# 0                               Robbery  Burglary/Robbery              1
# 1       Burglary, Breaking and Entering  Burglary/Robbery              1
# 2       Burglary, Breaking and Entering  Burglary/Robbery              1
# 3                   Motor vehicle theft             Theft              1
# ...

# %%
criminal_activity_df = crime_df[["Incident","Date","Hour","Offense_Type","Offense_Grouped","Beat","Premise","Street_No","Street_Name","Street_Type" ]]
criminal_activity_df["ID"] = criminal_activity_df.index + 1
criminal_activity_df
# Out:
# <ipython-input-10-adfef695dc42>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   criminal_activity_df["ID"] = criminal_activity_df.index + 1
#          Incident        Date  Hour                     Offense_Type  \
# 0           79220  2020-01-01     0                          Robbery
# 1        59342520  2020-01-01     0  Burglary, Breaking and Entering
# 2       123324720  2020-01-01     0  Burglary, Breaking and Entering
# 3          233120  2020-01-01     0              Motor vehicle theft
# 4          240920  2020-01-01     0              Motor vehicle theft
# ...           ...         ...   ...                              ...
# 354130  133031021  2021-09-30    23   Destruction, damage, vandalism
# ...

# %%
criminal_activity_df.to_csv('criminal_activity_df.csv', index=False)

# %% [markdown]
# # #Population data  SQL cleanup

# %%
population_df = pd.read_csv("5_Population_Data.csv")
population_df
# Out:
#      Zipcode Population Population Density Housing Units Median Home Value  \
# 0      77062     25,152              4,637         9,910         $160,100
# 1      77048     15,294              1,380         6,501          $81,200
# 2      77055     41,989              5,023        16,005         $230,300
# 3      77085     16,074              3,036         4,857         $106,600
# 4      77082     49,900              3,975        23,058         $124,000
# ..       ...        ...                ...           ...               ...
# 169    77318     14,281                372         6,780         $166,100
# 170    77550     23,043              3,069        14,615         $117,200
# 171    77372     12,164                234         4,544          $75,800
# 172    77485      4,054                 49         1,769         $135,800
# 173    77010        366              2,965           471         $526,300
#
# ...

# %%
population_df = population_df.rename(columns = {  "Zipcode": "Zip_Code", 
                                                  "Population Density": "Population_Density",
                                                  "Housing Units": "Housing_Units",
                                                  "Median Home Value": "Median_Home_Value",
                                                  "White":"Race_White",
                                                  "Black":"Race_Black",
                                                  "Indian":"Race_Indian",
                                                  "Asian":"Race_Asian",
                                                  "Hawaiian":"Race_Hawaiian",
                                                  "Other":"Race_Other",
                                                  "Mixed":"Race_Mixed"
                                               }
                                    )
    
population_df.head() 
population_df["ID"] = population_df.index + 1
population_df
# Out:
#      Zip_Code Population Population_Density Housing_Units Median_Home_Value  \
# 0       77062     25,152              4,637         9,910         $160,100
# 1       77048     15,294              1,380         6,501          $81,200
# 2       77055     41,989              5,023        16,005         $230,300
# 3       77085     16,074              3,036         4,857         $106,600
# 4       77082     49,900              3,975        23,058         $124,000
# ..        ...        ...                ...           ...               ...
# 169     77318     14,281                372         6,780         $166,100
# 170     77550     23,043              3,069        14,615         $117,200
# 171     77372     12,164                234         4,544          $75,800
# 172     77485      4,054                 49         1,769         $135,800
# 173     77010        366              2,965           471         $526,300
#
# ...

# %%
population_df.to_csv('population.csv', index=False)

# %% [markdown]
# # #Create a new DF for Tracts

# %%
tract_zip_lat_long_df = crime_df[["Full_Address","Census_Tract","Zip_Code","Latitude","Longitude"]] 
tract_zip_lat_long_df['Full_Address'] = crime_df['Full_Address'].replace(', Houston, TX', '', regex=True)



tract_zip_lat_long_df
# Out:
# <ipython-input-19-435e7a4851a2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tract_zip_lat_long_df['Full_Address'] = crime_df['Full_Address'].replace(', Houston, TX', '', regex=True)
#                          Full_Address  Census_Tract  Zip_Code   Latitude  \
# 0               16302 EL CAMINO REAL       340701.0     77062  29.560020
# 1       12000 MARTIN LUTHER KING BLVD      331604.0     77048        NaN
# 2                       9440 KATY FWY      522301.0     77055  29.785149
# 3                       14711 MAIN ST           NaN     77085  29.676383
# 4                 3030 SHADOWBRIAR DR      452002.0     77082  29.731948
# ...                               ...           ...       ...        ...
# ...

# %%
tract_zip_lat_long_df["ID"] = tract_zip_lat_long_df.index + 1
tract_zip_lat_long_df
# Out:
# <ipython-input-21-4a7f9520681d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tract_zip_lat_long_df["ID"] = tract_zip_lat_long_df.index + 1
#                          Full_Address  Census_Tract  Zip_Code   Latitude  \
# 0               16302 EL CAMINO REAL       340701.0     77062  29.560020
# 1       12000 MARTIN LUTHER KING BLVD      331604.0     77048        NaN
# 2                       9440 KATY FWY      522301.0     77055  29.785149
# 3                       14711 MAIN ST           NaN     77085  29.676383
# 4                 3030 SHADOWBRIAR DR      452002.0     77082  29.731948
# ...                               ...           ...       ...        ...
# 354130                4417 NICHOLS ST      211301.0     77020  29.781080
# ...

# %%
tract_zip_lat_long_df.to_csv('location_df.csv', index=False)
